# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Datasets

# %% [markdown]
# ## Original Dataset

# %%
y_true_og_fold1_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/ytrue_og_fold_1.csv')['0']
y_pred_og_fold1_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/ypred_og_fold_1.csv')['0']
y_prob_og_fold1_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/yprob_og_fold_1.csv')

y_true_og_fold2_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/ytrue_og_fold_2.csv')['0']
y_pred_og_fold2_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/ypred_og_fold_2.csv')['0']
y_prob_og_fold2_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/yprob_og_fold_2.csv')

y_true_og_fold3_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/ytrue_og_fold_3.csv')['0']
y_pred_og_fold3_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/ypred_og_fold_3.csv')['0']
y_prob_og_fold3_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/yprob_og_fold_3.csv')

y_true_og_fold4_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/ytrue_og_fold_4.csv')['0']
y_pred_og_fold4_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/ypred_og_fold_4.csv')['0']
y_prob_og_fold4_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/yprob_og_fold_4.csv')

y_true_og_fold5_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/ytrue_og_fold_5.csv')['0']
y_pred_og_fold5_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/ypred_og_fold_5.csv')['0']
y_prob_og_fold5_df = pd.read_csv('../../Output/original_dataset_results/Evaluation_Output/yprob_og_fold_5.csv')

# %% [markdown]
# ## L1 Feature Reduced Dataset

# %%
y_true_l1_fold1_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/ytrue_l1_fold_1.csv')['0']
y_pred_l1_fold1_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/ypred_l1_fold_1.csv')['0']
y_score_l1_fold1_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/yprob_l1_fold_1.csv')

y_true_l1_fold2_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/ytrue_l1_fold_2.csv')['0']
y_pred_l1_fold2_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/ypred_l1_fold_2.csv')['0']
y_score_l1_fold2_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/yprob_l1_fold_2.csv')

y_true_l1_fold3_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/ytrue_l1_fold_3.csv')['0']
y_pred_l1_fold3_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/ypred_l1_fold_3.csv')['0']
y_score_l1_fold3_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/yprob_l1_fold_3.csv')

y_true_l1_fold4_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/ytrue_l1_fold_4.csv')['0']
y_pred_l1_fold4_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/ypred_l1_fold_4.csv')['0']
y_score_l1_fold4_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/yprob_l1_fold_4.csv')

y_true_l1_fold5_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/ytrue_l1_fold_5.csv')['0']
y_pred_l1_fold5_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/ypred_l1_fold_5.csv')['0']
y_score_l1_fold5_df = pd.read_csv('../../Output/l1_results/Evaluation_Output/yprob_l1_fold_5.csv')

# %% [markdown]
# ## Mutual Information Reduced Dataset

# %%
y_true_MI_fold1_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/ytrue_mutual_information_fold_1.csv')['0']
y_pred_MI_fold1_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/ypred_mutual_information_fold_1.csv')['0']
y_score_MI_fold1_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/yprob_mutual_information_fold_1.csv')

y_true_MI_fold2_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/ytrue_mutual_information_fold_2.csv')['0']
y_pred_MI_fold2_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/ypred_mutual_information_fold_2.csv')['0']
y_score_MI_fold2_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/yprob_mutual_information_fold_2.csv')

y_true_MI_fold3_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/ytrue_mutual_information_fold_3.csv')['0']
y_pred_MI_fold3_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/ypred_mutual_information_fold_3.csv')['0']
y_score_MI_fold3_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/yprob_mutual_information_fold_3.csv')

y_true_MI_fold4_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/ytrue_mutual_information_fold_4.csv')['0']
y_pred_MI_fold4_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/ypred_mutual_information_fold_4.csv')['0']
y_score_MI_fold4_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/yprob_mutual_information_fold_4.csv')

y_true_MI_fold5_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/ytrue_mutual_information_fold_5.csv')['0']
y_pred_MI_fold5_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/ypred_mutual_information_fold_5.csv')['0']
y_score_MI_fold5_df = pd.read_csv('../../Output/mutual_information_results/Evaluation_Output/yprob_mutual_information_fold_5.csv')

# %% [markdown]
# ## Variance Filtering Reduced Dataset

# %%
y_true_variance_filtering_fold1_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/ytrue_variance_filtering_fold_1.csv')['0']
y_pred_variance_filtering_fold1_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/ypred_variance_filtering_fold_1.csv')['0']
y_score_variance_filtering_fold1_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/yprob_variance_filtering_fold_1.csv')

y_true_variance_filtering_fold2_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/ytrue_variance_filtering_fold_2.csv')['0']
y_pred_variance_filtering_fold2_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/ypred_variance_filtering_fold_2.csv')['0']
y_score_variance_filtering_fold2_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/yprob_variance_filtering_fold_2.csv')

y_true_variance_filtering_fold3_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/ytrue_variance_filtering_fold_3.csv')['0']
y_pred_variance_filtering_fold3_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/ypred_variance_filtering_fold_3.csv')['0']
y_score_variance_filtering_fold3_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/yprob_variance_filtering_fold_3.csv')

y_true_variance_filtering_fold4_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/ytrue_variance_filtering_fold_4.csv')['0']
y_pred_variance_filtering_fold4_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/ypred_variance_filtering_fold_4.csv')['0']
y_score_variance_filtering_fold4_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/yprob_variance_filtering_fold_4.csv')

y_true_variance_filtering_fold5_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/ytrue_variance_filtering_fold_5.csv')['0']
y_pred_variance_filtering_fold5_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/ypred_variance_filtering_fold_5.csv')['0']
y_score_variance_filtering_fold5_df = pd.read_csv('../../Output/variance_filtering_results/Evaluation_Output/yprob_variance_filtering_fold_5.csv')

# %% [markdown]
# # Class-Specific Metrics

# %%
fold_accuracies = []

# %% [markdown]
# ## Fold1

# %%
fold1_rpt = pd.DataFrame(classification_report(y_true_MI_fold1_df, y_pred_MI_fold1_df, target_names=['PRAD', 'LUAD', 'BRCA', 'KIRC', 'COAD'], sample_weight=None, output_dict=True, zero_division='warn')).T.round(4)
fold1_rpt = fold1_rpt.drop('weighted avg', axis=0)
accuracy1 = fold1_rpt.loc['accuracy','precision']
fold_accuracies.append(accuracy1)
fold1_rpt = fold1_rpt.drop('accuracy', axis=0)
fold1_rpt
# Out:
#            precision  recall  f1-score  support
# PRAD             1.0     1.0       1.0     60.0
# LUAD             1.0     1.0       1.0     16.0
# BRCA             1.0     1.0       1.0     29.0
# KIRC             1.0     1.0       1.0     28.0
# COAD             1.0     1.0       1.0     28.0
# macro avg        1.0     1.0       1.0    161.0

# %% [markdown]
# ## Fold2

# %%
fold2_rpt = pd.DataFrame(classification_report(y_true_MI_fold2_df, y_pred_MI_fold2_df, target_names=['PRAD', 'LUAD', 'BRCA', 'KIRC', 'COAD'], sample_weight=None, output_dict=True, zero_division='warn')).T.round(4)
fold2_rpt = fold2_rpt.drop('weighted avg', axis=0)
accuracy2 = fold2_rpt.loc['accuracy','precision']
fold_accuracies.append(accuracy2)
fold2_rpt = fold2_rpt.drop('accuracy', axis=0)
fold2_rpt
# Out:
#            precision  recall  f1-score  support
# PRAD             1.0     1.0       1.0     60.0
# LUAD             1.0     1.0       1.0     15.0
# BRCA             1.0     1.0       1.0     29.0
# KIRC             1.0     1.0       1.0     29.0
# COAD             1.0     1.0       1.0     27.0
# macro avg        1.0     1.0       1.0    160.0

# %% [markdown]
# ## Fold3

# %%
fold3_rpt = pd.DataFrame(classification_report(y_true_MI_fold3_df, y_pred_MI_fold3_df, target_names=['PRAD', 'LUAD', 'BRCA', 'KIRC', 'COAD'], sample_weight=None, output_dict=True, zero_division='warn')).T.round(4)
fold3_rpt = fold3_rpt.drop('weighted avg', axis=0)
accuracy3 = fold3_rpt.loc['accuracy','precision']
fold_accuracies.append(accuracy3)
fold3_rpt = fold3_rpt.drop('accuracy', axis=0)
fold3_rpt
# Out:
#            precision  recall  f1-score  support
# PRAD          0.9836  1.0000    0.9917     60.0
# LUAD          1.0000  1.0000    1.0000     15.0
# BRCA          1.0000  1.0000    1.0000     30.0
# KIRC          1.0000  0.9643    0.9818     28.0
# COAD          1.0000  1.0000    1.0000     27.0
# macro avg     0.9967  0.9929    0.9947    160.0

# %% [markdown]
# ## Fold4

# %%
fold4_rpt = pd.DataFrame(classification_report(y_true_MI_fold4_df, y_pred_MI_fold4_df, target_names=['PRAD', 'LUAD', 'BRCA', 'KIRC', 'COAD'], sample_weight=None, output_dict=True, zero_division='warn')).T.round(4)
fold4_rpt = fold4_rpt.drop('weighted avg', axis=0)
accuracy4 = fold4_rpt.loc['accuracy','precision']
fold_accuracies.append(accuracy4)
fold4_rpt = fold4_rpt.drop('accuracy', axis=0)
fold4_rpt
# Out:
#            precision  recall  f1-score  support
# PRAD             1.0     1.0       1.0     60.0
# LUAD             1.0     1.0       1.0     16.0
# BRCA             1.0     1.0       1.0     29.0
# KIRC             1.0     1.0       1.0     28.0
# COAD             1.0     1.0       1.0     27.0
# macro avg        1.0     1.0       1.0    160.0

# %% [markdown]
# ## Fold5

# %%
fold5_rpt = pd.DataFrame(classification_report(y_true_MI_fold5_df, y_pred_MI_fold5_df, target_names=['PRAD', 'LUAD', 'BRCA', 'KIRC', 'COAD'], sample_weight=None, output_dict=True, zero_division='warn')).T.round(4)
fold5_rpt = fold5_rpt.drop('weighted avg', axis=0)
accuracy5 = fold5_rpt.loc['accuracy','precision']
fold_accuracies.append(accuracy5)
fold5_rpt = fold5_rpt.drop('accuracy', axis=0)
fold5_rpt
# Out:
#            precision  recall  f1-score  support
# PRAD          0.9836  1.0000    0.9917     60.0
# LUAD          1.0000  1.0000    1.0000     16.0
# BRCA          1.0000  1.0000    1.0000     29.0
# KIRC          1.0000  0.9643    0.9818     28.0
# COAD          1.0000  1.0000    1.0000     27.0
# macro avg     0.9967  0.9929    0.9947    160.0

# %% [markdown]
# ## Accuracy Table

# %%
fold_acc_avg = np.mean(fold_accuracies)

# %%
accuracy_df = pd.DataFrame([fold_accuracies + [fold_acc_avg]], columns=["Fold1", "Fold2", "Fold3", "Fold4", "Fold5", "Fold Avg"], index=['Accuracy'])
accuracy_df
# Out:
#           Fold1  Fold2   Fold3  Fold4   Fold5  Fold Avg
# Accuracy    1.0    1.0  0.9938    1.0  0.9938   0.99752

# %% [markdown]
# # Confusion Matrix

# %% [markdown]
# ## Fold 1

# %%
raw_conf_matrix1 = confusion_matrix(y_true_MI_fold1_df, y_pred_MI_fold1_df, sample_weight=None, normalize=None)
norm_conf_matrix1 = confusion_matrix(y_true_MI_fold1_df, y_pred_MI_fold1_df, sample_weight=None, normalize='true')

# %%
sns.heatmap(norm_conf_matrix1, cmap='GnBu', annot=True, fmt='.4f', linecolor='black', linewidths=0.5, xticklabels=['Pred PRAD', 'Pred LUAD', 'Pred BRCA', 'Pred KIRC', 'Pred COAD'], yticklabels=['True PRAD', 'True LUAD', 'True BRCA', 'True KIRC', 'True COAD'])
# Out:
# <Axes: >

# %%
sns.heatmap(raw_conf_matrix1, cmap='GnBu', annot=True, fmt='.0f', linecolor='black', linewidths=0.5, xticklabels=['Pred PRAD', 'Pred LUAD', 'Pred BRCA', 'Pred KIRC', 'Pred COAD'], yticklabels=['True PRAD', 'True LUAD', 'True BRCA', 'True KIRC', 'True COAD'])
# Out:
# <Axes: >

# %% [markdown]
# ## Fold 2

# %%
raw_conf_matrix2 = confusion_matrix(y_true_MI_fold2_df, y_pred_MI_fold2_df, sample_weight=None, normalize=None)
norm_conf_matrix2 = confusion_matrix(y_true_MI_fold2_df, y_pred_MI_fold2_df, sample_weight=None, normalize='true')

# %%
sns.heatmap(norm_conf_matrix2, cmap='GnBu', annot=True, fmt='.4f', linecolor='black', linewidths=0.5, xticklabels=['Pred PRAD', 'Pred LUAD', 'Pred BRCA', 'Pred KIRC', 'Pred COAD'], yticklabels=['True PRAD', 'True LUAD', 'True BRCA', 'True KIRC', 'True COAD'])
# Out:
# <Axes: >

# %%
sns.heatmap(raw_conf_matrix2, cmap='GnBu', annot=True, fmt='.0f', linecolor='black', linewidths=0.5, xticklabels=['Pred PRAD', 'Pred LUAD', 'Pred BRCA', 'Pred KIRC', 'Pred COAD'], yticklabels=['True PRAD', 'True LUAD', 'True BRCA', 'True KIRC', 'True COAD'])
# Out:
# <Axes: >

# %% [markdown]
# ## Fold 3

# %%
raw_conf_matrix3 = confusion_matrix(y_true_MI_fold3_df, y_pred_MI_fold3_df, sample_weight=None, normalize=None)
norm_conf_matrix3 = confusion_matrix(y_true_MI_fold3_df, y_pred_MI_fold3_df, sample_weight=None, normalize='true')

# %%
sns.heatmap(norm_conf_matrix3, cmap='GnBu', annot=True, fmt='.4f', linecolor='black', linewidths=0.5, xticklabels=['Pred PRAD', 'Pred LUAD', 'Pred BRCA', 'Pred KIRC', 'Pred COAD'], yticklabels=['True PRAD', 'True LUAD', 'True BRCA', 'True KIRC', 'True COAD'])
# Out:
# <Axes: >

# %%
sns.heatmap(raw_conf_matrix3, cmap='GnBu', annot=True, fmt='.0f', linecolor='black', linewidths=0.5, xticklabels=['Pred PRAD', 'Pred LUAD', 'Pred BRCA', 'Pred KIRC', 'Pred COAD'], yticklabels=['True PRAD', 'True LUAD', 'True BRCA', 'True KIRC', 'True COAD'])
# Out:
# <Axes: >

# %% [markdown]
# ## Fold 4

# %%
raw_conf_matrix4 = confusion_matrix(y_true_MI_fold4_df, y_pred_MI_fold4_df, sample_weight=None, normalize=None)
norm_conf_matrix4 = confusion_matrix(y_true_MI_fold4_df, y_pred_MI_fold4_df, sample_weight=None, normalize='true')

# %%
sns.heatmap(norm_conf_matrix4, cmap='GnBu', annot=True, fmt='.4f', linecolor='black', linewidths=0.5, xticklabels=['Pred PRAD', 'Pred LUAD', 'Pred BRCA', 'Pred KIRC', 'Pred COAD'], yticklabels=['True PRAD', 'True LUAD', 'True BRCA', 'True KIRC', 'True COAD'])
# Out:
# <Axes: >

# %%
sns.heatmap(raw_conf_matrix4, cmap='GnBu', annot=True, fmt='.0f', linecolor='black', linewidths=0.5, xticklabels=['Pred PRAD', 'Pred LUAD', 'Pred BRCA', 'Pred KIRC', 'Pred COAD'], yticklabels=['True PRAD', 'True LUAD', 'True BRCA', 'True KIRC', 'True COAD'])
# Out:
# <Axes: >

# %% [markdown]
# ## Fold 5

# %%
raw_conf_matrix5 = confusion_matrix(y_true_MI_fold5_df, y_pred_MI_fold5_df, sample_weight=None, normalize=None)
norm_conf_matrix5 = confusion_matrix(y_true_MI_fold5_df, y_pred_MI_fold5_df, sample_weight=None, normalize='true')

# %%
sns.heatmap(norm_conf_matrix5, cmap='GnBu', annot=True, fmt='.4f', linecolor='black', linewidths=0.5, xticklabels=['Pred PRAD', 'Pred LUAD', 'Pred BRCA', 'Pred KIRC', 'Pred COAD'], yticklabels=['True PRAD', 'True LUAD', 'True BRCA', 'True KIRC', 'True COAD'])
# Out:
# <Axes: >

# %%
sns.heatmap(raw_conf_matrix5, cmap='GnBu', annot=True, fmt='.0f', linecolor='black', linewidths=0.5, xticklabels=['Pred PRAD', 'Pred LUAD', 'Pred BRCA', 'Pred KIRC', 'Pred COAD'], yticklabels=['True PRAD', 'True LUAD', 'True BRCA', 'True KIRC', 'True COAD'])
# Out:
# <Axes: >
